# %% [markdown]
# # House Price Prediction
#
# ### Internship Project - Week 1
#
# **Name:** Anshika Yadav
#
# **Objective:**
# To build machine learning models that predict house prices using housing features and compare their performance.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import os
os.makedirs("charts", exist_ok=True)

# %% [markdown]
# # Task 1 — Data Loading & Exploration

# %% [markdown]
#  #Load the CSV file using Pandas

# %%
df = pd.read_csv("Housing.csv")

# %% [markdown]
# #Display the first 10 rows

# %%
df.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %% [markdown]
# #Check how many rows and columns are there

# %%
print(df.shape)
# Out:
# (545, 13)

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# #Identify which column is the target (Price) and which are features

# %%
target = "price"
features = df.drop("price", axis=1)
print("Target:")
print(target)
print("\nFeatures:")
print(features.columns)
# Out:
# Target:
# price
#
# Features:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom',
#        'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefarea',
#        'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# #Check for missing values in each column

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# # Task 2 — Data Cleaning

# %% [markdown]
# #Handle missing values (fill or drop, whichever fits the column)
#  Remove duplicate rows, if any

# %% [markdown]
# #Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #Remove Duplicates

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# #Convert any categorical columns (e.g., yes/no fields) into numeric form using one-hot encoding
#  Keep only the columns that are meaningful for predicting price

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0  13300000  7420         4          2        3        2          True
# 1  12250000  8960         4          4        4        3          True
# 2  12250000  9960         3          2        2        2          True
# 3  12215000  7500         4          2        2        3          True
# 4  11410000  7420         4          1        2        2          True
#
#    guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# 0          False         False                False                 True
# 1          False         False                False                 True
# 2          False          True                False                False
# 3          False          True                False                 True
# 4           True          True                False                 True
#
#    prefarea_yes  furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# ...

# %% [markdown]
# # Task 3 — Model Building

# %% [markdown]
# ## Model 1

# %% [markdown]
# #Split the data into training and test sets (80/20)

# %%
X = df.drop("price", axis=1)
y = df["price"]

# %% [markdown]
# #Train a Linear Regression model to predict house price

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_pred = lr.predict(X_test)

# %% [markdown]
#  #Evaluate it using MAE, RMSE, and R² Score

# %%
mae_lr = mean_absolute_error(y_test, lr_pred)
rmse_lr = np.sqrt(mean_squared_error(y_test, lr_pred))
r2_lr = r2_score(y_test, lr_pred)
print("MAE:", mae_lr)
print("RMSE:", rmse_lr)
print("R2:", r2_lr)
# Out:
# MAE: 970043.4039201637
# RMSE: 1324506.9600914388
# R2: 0.6529242642153184

# %% [markdown]
# ## Model 2

# %% [markdown]
# #Train a second model — Random Forest Regressor — and compare its performance to the Linear Regression model

# %%
rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_pred = rf.predict(X_test)

# %% [markdown]
#  #Evaluate it using MAE, RMSE, and R² Score

# %%
mae_rf = mean_absolute_error(y_test, rf_pred)

rmse_rf = np.sqrt(mean_squared_error(y_test, rf_pred))

r2_rf = r2_score(y_test, rf_pred)

print("MAE:", mae_rf)
print("RMSE:", rmse_rf)
print("R2:", r2_rf)
# Out:
# MAE: 1021546.0353211008
# RMSE: 1400565.9728553821
# R2: 0.611918531405699

# %% [markdown]
# ### MODEL COMPARISON TABLE

# %%
comparison = pd.DataFrame({
    "Model":["Linear Regression","Random Forest"],
    "MAE":[mae_lr,mae_rf],
    "RMSE":[rmse_lr,rmse_rf],
    "R2 Score":[r2_lr,r2_rf]
})

comparison
# Out:
#                Model           MAE          RMSE  R2 Score
# 0  Linear Regression  9.700434e+05  1.324507e+06  0.652924
# 1      Random Forest  1.021546e+06  1.400566e+06  0.611919

# %% [markdown]
# # Task 4 — Visualization

# %% [markdown]
# ### Chart 1: Histogram showing the distribution of house prices

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["price"], bins=30, kde=True)
plt.title("House Price Distribution")
plt.savefig("charts/price_distribution.png", bbox_inches="tight")
plt.show()
plt.close()

# %% [markdown]
# ### Chart 2: Correlation heatmap showing which features relate most strongly to price

# %%
plt.figure(figsize=(12,8))
sns.heatmap(
    df.corr(),
    cmap="coolwarm"
)
plt.title("Correlation Heatmap")
plt.savefig(
    "charts/correlation_heatmap.png",
    bbox_inches="tight",
    dpi=300
)
plt.show()
plt.close()

# %% [markdown]
# ### Chart 3: A chart of your own choice — be creative

# %%
plt.figure(figsize=(8,6))

plt.scatter(y_test, rf_pred)

plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")

plt.title("Actual vs Predicted House Prices")

plt.savefig(
    "charts/actual_vs_predicted.png",
    bbox_inches="tight",
    dpi=300
)

plt.show()
plt.close()

# %% [markdown]
# ### FEATURE IMPORTANCE

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance.head(10)
# Out:
#                          Feature  Importance
# 0                           area    0.468430
# 2                      bathrooms    0.151483
# 9            airconditioning_yes    0.062672
# 4                        parking    0.057455
# 3                        stories    0.057133
# 1                       bedrooms    0.048413
# 12  furnishingstatus_unfurnished    0.035011
# 7                   basement_yes    0.030823
# 10                  prefarea_yes    0.030689
# 8            hotwaterheating_yes    0.017226

# %% [markdown]
# ### Feature Importance Chart

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x="Importance",
    y="Feature",
    data=importance.head(10)
)

plt.title("Top 10 Features Affecting House Prices")

plt.savefig(
    "charts/feature_importance.png",
    bbox_inches="tight",
    dpi=300
)

plt.show()
plt.close()

# %% [markdown]
# # Task 5 — Insights & Summary

# %% [markdown]
# ### Insights and Conclusion
#
# The analysis showed that area, number of bathrooms, stories, and air conditioning were among the most influential factors affecting house prices. Random Forest Regressor performed better than Linear Regression, indicating that house pricing depends on complex relationships between variables. The model achieved good predictive accuracy and was able to explain a large portion of the variation in house prices. One interesting observation was that preferred location and amenities significantly increased property value. Based on these findings, real estate businesses should focus on premium amenities and desirable locations to maximize property prices.
